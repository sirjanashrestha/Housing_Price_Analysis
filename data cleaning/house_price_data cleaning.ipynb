# %%
import pandas as pd
import datetime as dt

# %%
file = "house_price.xlsx"
df=pd.read_excel(file, engine='openpyxl',parse_dates=True)
df.reset_index()
df
# Out:
#           Date  Composite_HPI_SA  Single_Family_HPI_SA  One_Storey_HPI_SA  \
# 0   2005-01-01             100.0                 100.0              100.0
# 1   2005-02-01             100.6                 100.6              100.4
# 2   2005-03-01             101.4                 101.4              101.0
# 3   2005-04-01             102.2                 102.3              101.8
# 4   2005-05-01             102.8                 103.1              102.3
# ..         ...               ...                   ...                ...
# 208 2022-05-01             370.1                 385.8              360.0
# 209 2022-06-01             363.5                 378.3              350.7
# 210 2022-07-01             357.1                 370.7              343.7
# 211 2022-08-01             351.2                 363.8              337.3
# 212 2022-09-01             346.4                 359.9              332.3
#
#      Two_Storey_HPI_SA  Townhouse_HPI_SA  Apartment_HPI_SA  \
# ...

# %%
#df_sheet_index = pd.read_excel('house_price.xlsx',sheet_name='AGGREGATE')

# %%
df.dtypes
# Out:
# Date                          datetime64[ns]
# Composite_HPI_SA                     float64
# Single_Family_HPI_SA                 float64
# One_Storey_HPI_SA                    float64
# Two_Storey_HPI_SA                    float64
# Townhouse_HPI_SA                     float64
# Apartment_HPI_SA                     float64
# Composite_Benchmark_SA                 int64
# Single_Family_Benchmark_SA             int64
# One_Storey_Benchmark_SA                int64
# Two_Storey_Benchmark_SA                int64
# Townhouse_Benchmark_SA                 int64
# Apartment_Benchmark_SA                 int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Date                          0
# Composite_HPI_SA              0
# Single_Family_HPI_SA          0
# One_Storey_HPI_SA             0
# Two_Storey_HPI_SA             0
# Townhouse_HPI_SA              0
# Apartment_HPI_SA              0
# Composite_Benchmark_SA        0
# Single_Family_Benchmark_SA    0
# One_Storey_Benchmark_SA       0
# Two_Storey_Benchmark_SA       0
# Townhouse_Benchmark_SA        0
# Apartment_Benchmark_SA        0
# dtype: int64

# %%
df.describe()
# Out:
#        Composite_HPI_SA  Single_Family_HPI_SA  One_Storey_HPI_SA  \
# count        213.000000            213.000000         213.000000
# mean         198.544131            204.515023         191.926761
# std           66.477955             70.319619          61.952448
# min          100.000000            100.000000         100.000000
# 25%          147.800000            150.000000         150.000000
# 50%          176.800000            183.200000         171.800000
# 75%          248.100000            252.100000         233.500000
# max          379.900000            397.800000         370.300000
#
#        Two_Storey_HPI_SA  Townhouse_HPI_SA  Apartment_HPI_SA  \
# count         213.000000        213.000000        213.000000
# mean          203.490141        184.171831        186.692019
# std            71.090310         65.401483         60.004867
# min           100.000000        100.000000        100.000000
# 25%           145.800000        138.900000        144.600000
# ...

# %%
df['month_year'] = df['Date'].dt.to_period('M')
df
# Out:
#           Date  Composite_HPI_SA  Single_Family_HPI_SA  One_Storey_HPI_SA  \
# 0   2005-01-01             100.0                 100.0              100.0
# 1   2005-02-01             100.6                 100.6              100.4
# 2   2005-03-01             101.4                 101.4              101.0
# 3   2005-04-01             102.2                 102.3              101.8
# 4   2005-05-01             102.8                 103.1              102.3
# ..         ...               ...                   ...                ...
# 208 2022-05-01             370.1                 385.8              360.0
# 209 2022-06-01             363.5                 378.3              350.7
# 210 2022-07-01             357.1                 370.7              343.7
# 211 2022-08-01             351.2                 363.8              337.3
# 212 2022-09-01             346.4                 359.9              332.3
#
#      Two_Storey_HPI_SA  Townhouse_HPI_SA  Apartment_HPI_SA  \
# ...

# %%
df =df.drop(columns=['Date','Single_Family_HPI_SA','One_Storey_HPI_SA','Two_Storey_HPI_SA','Townhouse_HPI_SA','Apartment_HPI_SA','Single_Family_Benchmark_SA','One_Storey_Benchmark_SA','Two_Storey_Benchmark_SA','Townhouse_Benchmark_SA','Apartment_Benchmark_SA'])
df
# Out:
#      Composite_HPI_SA  Composite_Benchmark_SA month_year
# 0               100.0                  221100    2005-01
# 1               100.6                  222500    2005-02
# 2               101.4                  224200    2005-03
# 3               102.2                  225900    2005-04
# 4               102.8                  227400    2005-05
# ..                ...                     ...        ...
# 208             370.1                  818300    2022-05
# 209             363.5                  803600    2022-06
# 210             357.1                  789500    2022-07
# 211             351.2                  776500    2022-08
# 212             346.4                  766000    2022-09
#
# [213 rows x 3 columns]

# %%
df.rename(columns={'month_year':'date'})
# Out:
#      Composite_HPI_SA  Composite_Benchmark_SA     date
# 0               100.0                  221100  2005-01
# 1               100.6                  222500  2005-02
# 2               101.4                  224200  2005-03
# 3               102.2                  225900  2005-04
# 4               102.8                  227400  2005-05
# ..                ...                     ...      ...
# 208             370.1                  818300  2022-05
# 209             363.5                  803600  2022-06
# 210             357.1                  789500  2022-07
# 211             351.2                  776500  2022-08
# 212             346.4                  766000  2022-09
#
# [213 rows x 3 columns]
